# %%
import pandas as pd
import numpy as np
import re
import string

from sklearn.model_selection import train_test_split

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import nltk

print(nltk.__version__)
# Out:
# 3.9.4

# %%
nltk.download("stopwords")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Ahana
# [nltk_data]     Arora\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Ahana
# [nltk_data]     Arora\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\Ahana
# [nltk_data]     Arora\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Ahana Arora\OneDrive\Pictures\Documents\AI-Bug-Severity-Predictor\venv\Scripts\python.exe

# %%
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

print(stopwords.words("english")[:10])

lemmatizer = WordNetLemmatizer()
print(lemmatizer.lemmatize("running"))
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an']
# running

# %%
df = pd.read_csv("../../data/processed/issues_cleaned.csv")

df.head()
# Out:
#                                              summary  \
# 0  Update config browser to work with the new syntax
# 1  XALAN_C 1.9 or current do not build on Fedora ...
# 2        Problem with ADD new post, and DELETE post.
# 3  LogHandler can only work in GlobalConfiguratio...
# 4  Decoding of service is broken in org.apache.ax...
#
#                                          description priority.name  \
# 0  The config browser used Velocity calling the t...         Minor
# 1  Two types of errors:\n1- runConfigure and conf...       Blocker
# 2  When trying to add new post, I was getting nex...      Critical
# 3  org.apache.axis.handlers.LogHandler in request...         Major
# 4  The following code assumes a lot of things:\n\...         Major
#
#   status.name   resolution.name issuetype.name
# 0      Closed             Fixed    Improvement
# 1    Resolved             Fixed            Bug
# 2      Closed  Cannot Reproduce            Bug
# 3        Open           Unknown            Bug
# 4        Open           Unknown            Bug

# %%
df.to_csv("../../data/processed/final_dataset.csv", index=False)

# %%
.
