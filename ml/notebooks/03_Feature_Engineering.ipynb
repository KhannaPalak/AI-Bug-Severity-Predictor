# %%
import pandas as pd

import pickle

from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../../data/processed/final_dataset.csv")

# %%
df.head()
# Out:
#                                                 text  target
# 0  update config browser work new syntax config b...       5
# 1  xalanc 19 current build fedora core 3 two type...       0
# 2  problem add new post delete post trying add ne...       1
# 3  loghandler work globalconfiguration clientconf...       4
# 4  decoding service broken orgapacheaxistransport...       4

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1147328 entries, 0 to 1147327
# Data columns (total 2 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   text    1129198 non-null  str
#  1   target  1147328 non-null  int64
# dtypes: int64(1), str(1)
# memory usage: 17.5 MB

# %%
df.isnull().sum()
# Out:
# text      18130
# target        0
# dtype: int64

# %%
X = df["text"]

y = df["target"]

# %%
print(X.head())
# Out:
# 0    update config browser work new syntax config b...
# 1    xalanc 19 current build fedora core 3 two type...
# 2    problem add new post delete post trying add ne...
# 3    loghandler work globalconfiguration clientconf...
# 4    decoding service broken orgapacheaxistransport...
# Name: text, dtype: str

# %%
print(y.head())
# Out:
# 0    5
# 1    0
# 2    1
# 3    4
# 4    4
# Name: target, dtype: int64

# %%
tfidf = TfidfVectorizer(
    max_features=5000,
    ngram_range=(1,2),
    min_df=2
)

# %%
print(df.isnull().sum())

print(df["text"].isnull().sum())

print(df[df["text"].isnull()])
# Out:
# text      18130
# target        0
# dtype: int64
# 18130
#         text  target
# 21124    NaN       5
# 85458    NaN       4
# 182307   NaN       4
# 182876   NaN       4
# 200574   NaN       4
# ...      ...     ...
# 1147173  NaN      15
# 1147174  NaN      15
# 1147175  NaN      15
# 1147176  NaN      15
# 1147177  NaN      15
#
# [18130 rows x 2 columns]

# %%
print(df["text"].dtype)
# Out:
# str

# %%
df["text"] = df["text"].fillna("").astype(str)

# %%
X = df["text"]
y = df["target"]

# %%
X_features = tfidf.fit_transform(X)

# %%
print(X_features.shape)
# Out:
# (1147328, 5000)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_features,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

# %%
with open("../../models/tfidf_vectorizer.pkl","wb") as f:
    pickle.dump(tfidf,f)

# %%
print(X_train.shape)

print(X_test.shape)

print(y_train.shape)

print(y_test.shape)
# Out:
# (917862, 5000)
# (229466, 5000)
# (917862,)
# (229466,)

# %%
print(tfidf.get_feature_names_out()[:20])
# Out:
# ['00' '00 00' '00 io' '00 tid' '000' '0000' '0000 0000' '00000' '000000'
#  '0000000' '00000000' '00000000 0000' '00000000 0811' '0000ns' '001' '01'
#  '010' '012254' '02' '03']
